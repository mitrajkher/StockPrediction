# %%
#Importing the required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading the Dataset
data=pd.read_csv("NETFLIX.csv")
data
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    02-01-2019  259.279999  269.750000  ...  267.660004  267.660004  11679500
# 1    03-01-2019  270.200012  275.790009  ...  271.200012  271.200012  14969600
# 2    04-01-2019  281.880005  297.799988  ...  297.570007  297.570007  19330100
# 3    07-01-2019  302.100006  316.799988  ...  315.339996  315.339996  18620100
# 4    08-01-2019  319.980011  320.589996  ...  320.269989  320.269989  15359200
# ..          ...         ...         ...  ...         ...         ...       ...
# 237  10-12-2019  296.119995  298.940002  ...  293.119995  293.119995  10476100
# 238  11-12-2019  294.489990  299.429993  ...  298.929993  298.929993   5589800
# 239  12-12-2019  295.670013  299.170013  ...  298.440002  298.440002   4766600
# 240  13-12-2019  298.500000  301.799988  ...  298.500000  298.500000   3879700
# 241  16-12-2019  300.850006  305.709991  ...  304.209991  304.209991   4658900
#
# [242 rows x 7 columns]

# %%
# Printing the first 10 rows of Data
data.head(10)
# Out:
#          Date        Open        High  ...       Close   Adj Close    Volume
# 0  02-01-2019  259.279999  269.750000  ...  267.660004  267.660004  11679500
# 1  03-01-2019  270.200012  275.790009  ...  271.200012  271.200012  14969600
# 2  04-01-2019  281.880005  297.799988  ...  297.570007  297.570007  19330100
# 3  07-01-2019  302.100006  316.799988  ...  315.339996  315.339996  18620100
# 4  08-01-2019  319.980011  320.589996  ...  320.269989  320.269989  15359200
# 5  09-01-2019  317.709991  323.350006  ...  319.959991  319.959991  13343200
# 6  10-01-2019  314.570007  325.369995  ...  324.660004  324.660004  13472500
# 7  11-01-2019  330.959991  341.089996  ...  337.589996  337.589996  19500400
# 8  14-01-2019  334.239990  335.480011  ...  332.940002  332.940002  10499600
# 9  15-01-2019  349.600006  357.220001  ...  354.640015  354.640015  21181200
#
# [10 rows x 7 columns]

# %%
#Checing the dimensions of Data
df.shape
# Out:
# (242, 7)

# %%
#Statistical Summary
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count  242.000000  242.000000  242.000000  242.000000  242.000000  2.420000e+02
# mean   328.690125  333.077025  324.095537  328.907189  328.907189  7.910557e+06
# std     35.485602   35.378773   35.264082   35.172537   35.172537  4.699169e+06
# min    255.710007  265.000000  252.279999  254.589996  254.589996  2.411700e+06
# 25%    295.259994  299.154999  291.085007  295.212502  295.212502  5.160175e+06
# 50%    335.925003  341.434998  329.964996  337.819992  337.819992  6.390800e+06
# 75%    360.127503  364.674995  355.162506  359.865006  359.865006  8.762700e+06
# max    382.769989  385.989990  378.799988  385.029999  385.029999  3.825890e+07

# %%
#More information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       242 non-null    object
#  1   Open       242 non-null    float64
#  2   High       242 non-null    float64
#  3   Low        242 non-null    float64
#  4   Close      242 non-null    float64
#  5   Adj Close  242 non-null    float64
#  6   Volume     242 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.4+ KB

# %%
# Data types of Variables
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#Checking for the null values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Plotting b/w Date and Close 
plt.scatter(data.Date,data.Close,color = 'red', s = 50,marker = '.')
plt.title("Date Vs Closing Price")
plt.xlabel('Date', color = 'Blue')
plt.ylabel('Closing Price', color = 'Blue')
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
#Visualizing the History of Opening price
plt.figure(figsize=(14,7))
plt.plot(data['Open'],color = 'red')
plt.title('History of Opening Price', fontsize=18, color = 'red')
plt.xlabel('Date')
plt.ylabel('Opening Price')

#Visualizing the History of Highs
plt.figure(figsize=(14,7))
plt.plot(data['High'],color ='green')
plt.title('History of Highs', fontsize=18, color = 'red')
plt.xlabel('Date')
plt.ylabel('Highs')

#Visualizing the History of Lows
plt.figure(figsize=(14,7))
plt.plot(data['Low'],color = 'blue')
plt.title('History of Lows', fontsize=18, color = 'red')
plt.xlabel('Date')
plt.ylabel('Lows')

#Visualizing the History of CLosing Price
plt.figure(figsize=(14,7))
plt.plot(data['Close'], color='orange')
plt.title('History of Closing Price', fontsize=18, color = 'red')
plt.xlabel('Date')
plt.ylabel('Closing Price')
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
#Training Data
train = data.iloc[:,1:5]
train
# Out:
#            Open        High         Low       Close
# 0    259.279999  269.750000  256.579987  267.660004
# 1    270.200012  275.790009  264.429993  271.200012
# 2    281.880005  297.799988  278.540009  297.570007
# 3    302.100006  316.799988  301.649994  315.339996
# 4    319.980011  320.589996  308.010010  320.269989
# ..          ...         ...         ...         ...
# 237  296.119995  298.940002  292.019989  293.119995
# 238  294.489990  299.429993  294.200012  298.929993
# 239  295.670013  299.170013  295.059998  298.440002
# 240  298.500000  301.799988  297.250000  298.500000
# 241  300.850006  305.709991  298.630005  304.209991
#
# [242 rows x 4 columns]

# %%
#Trainiing data columns
train.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
#Visualization of above training columns

plt.figure(figsize=(20,10))
plt.plot(train.Open.values, color = 'red', label = 'OPEN')
plt.plot(train.High.values, color = 'green', label = 'HIGH')
plt.plot(train.Low.values, color = 'blue', label = 'LOW')
plt.plot(train.Close.values, color = 'yellow', label = 'CLOSE')
plt.xlabel('Date',fontsize=20)
plt.ylabel('Price',fontsize=20)
# Out:
# Text(0, 0.5, 'Price')

# %%
#Printing the columns
cols = list(train.columns.values)
print(cols)
# Out:
# ['Open', 'High', 'Low', 'Close']

# %%
#Scaling the data
from sklearn.preprocessing import MinMaxScaler

temp = MinMaxScaler(feature_range = (0,1))
train_scaled = temp.fit_transform(train)
train_scaled
# Out:
# array([[0.0280969 , 0.03925945, 0.03398663, 0.10019938],
#        [0.11404067, 0.08918101, 0.09603221, 0.12733836],
#        [0.2059657 , 0.27109671, 0.20755621, 0.32950023],
#        [0.36510314, 0.42813449, 0.39021498, 0.46573136],
#        [0.50582412, 0.45945946, 0.44048384, 0.50352646],
#        [0.48795839, 0.48227135, 0.48387612, 0.5011499 ],
#        [0.46324578, 0.49896686, 0.47597223, 0.5371819 ],
#        [0.59223984, 0.62889497, 0.60259245, 0.63630787],
#        [0.61805442, 0.58252762, 0.60741395, 0.60065934],
#        [0.73894233, 0.76221182, 0.74865641, 0.76701945],
#        [0.7735716 , 0.77568405, 0.75742961, 0.74210378],
#        [0.73815525, 0.75039273, 0.74399315, 0.75590313],
#        [0.7575949 , 0.7273329 , 0.66748355, 0.64788415],
#        [0.62317031, 0.59409878, 0.5433924 , 0.54101507],
#        [0.57091141, 0.55169853, 0.524186  , 0.51671261],
#        [0.51070367, 0.55211169, 0.52734751, 0.55259135],
# ...

# %%
#Windowing the data for LSTM Network
#size of window=40
f_data=[]
for i in range(len(train_scaled)-40):
  f_data.append(train_scaled[i:i+40])
f_data=np.array(f_data)
f_data.shape
# Out:
# (202, 40, 4)

# %%
#Splitting Test and Train Size
test=int(np.round(0.1*f_data.shape[0]))
# valid=int(np.round(0.1*f_data.shape[0]))
train=f_data.shape[0]-test
print(test,train)
# Out:
# 20 182

# %%
#Splitting Test and Train Data
x_train=f_data[:train,:-1,:]
y_train=f_data[:train,-1,:]
# x_valid=f_data[train:train+valid,:-1,:]
# y_valid=f_data[train:train+valid,-1,:]
x_test=f_data[train:,:-1,:]
y_test=f_data[train:,-1,:]
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (182, 39, 4) (182, 4) (20, 39, 4) (20, 4)

# %%
#Importing Libraries for training the model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras import metrics

# %%
#Building the structure of Model
model= Sequential()
model.add(LSTM(units = 500, return_sequences = True, input_shape = (x_train.shape[1],x_train.shape[2])))
model.add(Dropout(0.3))
model.add(LSTM(units = 400, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 400, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 400, return_sequences = True))
model.add(Dropout(0.1))
model.add(LSTM(units = 200))
model.add(Dropout(0.1))
model.add(Dense(units = 4))

model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics =[metrics.RootMeanSquaredError()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 39, 500)           1010000
# _________________________________________________________________
# dropout (Dropout)            (None, 39, 500)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 39, 400)           1441600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 39, 400)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 39, 400)           1281600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 39, 400)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 39, 400)           1281600
# ...

# %%
#Training the model
history=model.fit(x_train,y_train,epochs = 500,validation_data=(x_test,y_test), batch_size = 64)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.2696 - root_mean_squared_error: 0.5192 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1877
# Epoch 2/500
# 3/3 [==============================] - 5s 2s/step - loss: 0.4119 - root_mean_squared_error: 0.6418 - val_loss: 0.0999 - val_root_mean_squared_error: 0.3160
# Epoch 3/500
# 3/3 [==============================] - 5s 2s/step - loss: 0.2413 - root_mean_squared_error: 0.4912 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1918
# Epoch 4/500
# 3/3 [==============================] - 5s 2s/step - loss: 0.0811 - root_mean_squared_error: 0.2848 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1719
# Epoch 5/500
# 3/3 [==============================] - 5s 2s/step - loss: 0.0699 - root_mean_squared_error: 0.2645 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 6/500
# ...

# %%
#Visualising the comparison b/w model accuracy and model loss
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#For saving the model on disk
model_saved_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_saved_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.models import model_from_json
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
test=f_data[-1:,1:,:]
for i in range(2,12):
  j=0
  prediction=model.predict(test)
  test=test[:,i:,:]
  test=np.append(test,prediction.reshape(1,1,4),axis=1)
  prediction=temp.inverse_transform(prediction)
  print("\nDay ",i-1,':')
  print('OPEN :',prediction[0][j])
  j+=1
  print('HIGH :',prediction[0][j])
  j+=1
  print('LOW :',prediction[0][j])
  j+=1
  print('CLOSED : ',prediction[0][j])
# Out:
# Day  1 :
# OPEN : 306.4105
# HIGH : 310.47824
# LOW : 303.64825
# CLOSED :  307.8262
#
# Day  2 :
# OPEN : 300.5409
# HIGH : 304.63324
# LOW : 297.55164
# CLOSED :  301.49805
#
# Day  3 :
# OPEN : 294.844
# HIGH : 297.85522
# LOW : 291.41696
# CLOSED :  294.45993
#
# Day  4 :
# OPEN : 292.3383
# HIGH : 294.40887
# LOW : 288.69705
# CLOSED :  290.9252
#
# Day  5 :
# OPEN : 284.0038
# HIGH : 286.7712
# LOW : 279.38635
# CLOSED :  282.55432
#
# Day  6 :
# OPEN : 277.3559
# HIGH : 282.98956
# LOW : 271.3804
# CLOSED :  277.55423
#
# Day  7 :
# OPEN : 281.7295
# HIGH : 286.24097
# LOW : 277.41742
# CLOSED :  282.52158
#
# Day  8 :
# OPEN : 275.48505
# HIGH : 280.41818
# LOW : 271.4118
# CLOSED :  277.17825
#
# Day  9 :
# OPEN : 270.85532
# HIGH : 277.5593
# LOW : 266.32037
# CLOSED :  271.10654
#
# Day  10 :
# OPEN : 265.54294
# HIGH : 273.3986
# LOW : 261.56778
# CLOSED :  265.2784
